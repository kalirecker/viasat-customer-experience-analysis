# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive"
# Out:
#  0386ECDA-DD9F-4962-95FF-6B0666226A9D.png
#  08DA74A7-6E1E-46AF-B59E-E7CDC922C452.jpeg
#  1470472E-4246-4A14-9A99-35A935D98261.jpeg
#  4B7DEBE0-C021-4D5F-9F9B-3DA37797CB55.jpeg
#  4BD60C68-A2A6-46D2-BF3B-B56819A710C1.jpeg
# '5 Big Thinkers.gdoc'
#  5FC8BAD7-F47F-4F01-81E5-DB269FE36CBF.jpeg
# '60 things about him .gdoc'
#  8FDA3D99-1283-4F01-8267-31BBDF1E8EA9.png
# '90 second reflection.gdoc'
# '90 Sec Reflection.gdoc'
#  93227C70-FA37-4234-93A2-076B52B736C4.jpeg
# 'ADOPT A COB! <3.gslides'
#  aha_2015.csv
# 'Anchorman Nominations .gform'
# 'Anchorman Nominations  (Responses).gsheet'
# 'Anchorman nominees anonymous form .gform'
# 'Anchorman Survey .gform'
# 'Anchorman Vote 2.0.gform'
# 'Anchorman Vote.gform'
#  AnnotatedETL.gdoc
# 'assignment_01_part2 (1).drawio.png'
#  assignment_01_part2.drawio.png
#  assignment_01_partII.gdoc
# 'Assignment 1 ISBA 3730 Makayla Recker.gdoc'
# 'Assignment 1 Programming.gdoc'
# 'Assignment 2 #3 Data Warehouse Purpose.gdoc'
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/My Drive/Viasat_Tailored_Data.csv")

sns.lmplot(data=df, x="WiFi_Dropouts", y="Satisfaction_Score")
plt.title("Satisfaction Forecast vs Dropouts")
plt.show()
